# %%
from PIL import Image
im = Image.open("RedX.png")
#im.show()
display(im)
print(im.mode)
# Check out region (crop),paste
im2 = Image.open("AvalancheCircle.png")
display(im2)
print(im2.mode)
print(im2.size)
alpha = 0.5 # alpha is between 0 and 1
im_combined = Image.blend(im2,im,alpha)
display(im_combined)
im_combined = Image.alpha_composite(im2,im)
display(im_combined)

## Here's my current thought
# create an image that is blank/ all transparent
# place X and circles where they belong
# use alpha_composite to put the overlay ontop of the base/individual bracket
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x400 at 0x282579F6E60>
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x400 at 0x282587C33A0>
# RGBA
# (400, 400)
# <PIL.Image.Image image mode=RGBA size=400x400 at 0x282587C3F70>
# <PIL.Image.Image image mode=RGBA size=400x400 at 0x28257A27640>
